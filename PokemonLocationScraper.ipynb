# %%
import requests
import bs4
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
"""
get generation 2 spawn tables
"""

def get_spawn_tables(loc):
    """
    params:
    -------
        loc - url to search through 
    rets:
    -----
        res - generation 2 spawn tables scraped from loc url
    """
    
    loc_page = requests.get(loc)
    loc_soup = BeautifulSoup(loc_page.content, 'html.parser')
    
    # extract html between header tags
    start = loc_soup.find('h2', {'id': 'gen2'})
    html  = u''
    res   = []
    
    if (start is None):
        return []
    
    for elem in start.next_siblings:
        if elem.name == 'h2':
            break
        else:
            html += str(elem)

    soup   = BeautifulSoup(html, 'html.parser')
    tables = soup.find_all('table', {'class': 'data-table'})
    catch_methods = soup.find_all('h3')
    
    for i in range(len(tables)):
        res.append(tuple([loc[31:], catch_methods[i].text, tables[i]]))
        
    return res

# %%
"""
parse spawn table row
"""
def parse_spawn_table_row(row):
    """
    params:
    -------
        row - row to parse
    rets:
    -----
        res - tuple of the form [pokemon name | times available]
    """
    
    name         = row.find('td').find('span', {'class': 'infocard-data'}).find('a')['href'][9:]
    availability = []
    iterator     = 0
    times        = ['morning', 'day', 'night']
    
    for elem in row.find('td', {'class': 'cell-fixed'}).contents:
        if elem.name == 'img':
            availability.append(times[iterator])
            
        iterator += 1
        
    return tuple([name, availability])

# %%
"""
parse a single spawn table
"""

def parse_spawn_table(table):
    """
    params:
    -------
        table - table to parse. tuple (route, catch method, data table)
    rets:
    -----
        res - 2d matrix where each row is of form [pokemon name | routes available | times available | catch method]
    """
    
    route          = table[0]
    catch_method   = table[1]
    names          = []
    availabilities = []
    res            = []
    
    for row in table[2].find_all('tr')[1:]:
        name, availability = parse_spawn_table_row(row)
        names.append(name)
        availabilities.append(availability)
        
    for i in range(len(names)):
        res.append([names[i], route, availabilities[i], catch_method])
        
    return res

# %%
"""
parse all spawn tables
"""

def parse_spawn_tables():
    """
    params:
    -------
        NONE (relies on global var 'tables')
    rets:
    ----
         res - 2d matrix where each row is of form [pokemon name | routes available | times available | catch method]
    """
    
    res = []
    
    for table in tables:
        res += parse_spawn_table(table)
        
    return res

# %%
"""
union duplicate pokemon data
"""

def union_pokemon_guide():
    """
    params:
    -------
        NONE (relies on global var 'pokemon_location_guide')
    rets:
    -----
        res - unioned pokemon location guide (i.e. dupe pokemon have data unioned(?))
    """
    
    res   = []
    names = get_names()
    
    f_name   = ''
    f_routes = []
    f_times  = set()
    f_catch  = []
    
    for name in names:
        f_name   = ''
        f_routes = []
        f_times  = set()
        f_catch  = []
    
        to_union = [x for x in pokemon_location_guide if x[0] == name]
        f_name   = name
        f_routes = sorted(list(set([x[1] for x in to_union])))
        f_catch  = sorted(list(set([x[3] for x in to_union])))
        for data in to_union:
            for time in data[2]:
                if time not in f_times:
                    f_times.add(time)
        res.append([f_name, f_routes, list(f_times), f_catch])
        
    return res

# %%
"""
get all available pokemon names
"""

def get_names():
    """
    params:
    -------
        NONE (relies on global var 'pokemon_location_guide')
    rets:
    -----
        res - all pokemon names available
    """
    
    res = []
    
    for poke_data in pokemon_location_guide:
        res.append(poke_data[0])
        
    return sorted(list(set(res)))

# %% [markdown]
# SCRAPING BEGINS HERE

# %%
"""
base url
"""
base_url = 'https://pokemondb.net/location'
page     = requests.get(base_url)
soup     = BeautifulSoup(page.content, 'html.parser')
poke_df  = pd.DataFrame(columns=['routes available', 'time of day', 'capture method'], dtype='object')

# %%
"""
load route urls into locs
"""
locs = []
loc  = ''

for a in soup.find_all('a', href=re.compile(r'/location/kanto')):
    to_append     = a['href'][9:]
    loc  = base_url + to_append
    locs.append(loc)

# %%
"""
load generation 2 tables from each url
"""
tables = []

for loc in locs:
    tables += (get_spawn_tables(loc))

# %%
"""
parse loaded tables and put into 2d matrix (non-numpy)
"""
pokemon_location_guide = parse_spawn_tables()
pokemon_location_guide = sorted(pokemon_location_guide, key=lambda x: x[0])
pokemon_location_guide = union_pokemon_guide()

# %%
"""
flip generated 2d matrix for df generation
"""
to_df = list(zip(*reversed(pokemon_location_guide)))

# %%
"""
generate pandas dataframe
"""
pokemon_location_guide_d  = {'Pokemon': to_df[0], 'Routes Available': to_df[1], 'Times Available': to_df[2], 'Capture Methods': to_df[3]}
pokemon_location_guide_df = pd.DataFrame(pokemon_location_guide_d)
pokemon_location_guide_df.set_index('Pokemon', inplace=True)
pokemon_location_guide_df
# Out:
#                                     Capture Methods  \
# Pokemon
# zubat                                     [Walking]
# xatu                                        [Trade]
# weepinbell                                [Walking]
# weedle               [Headbutt, Headbutt (Special)]
# vulpix                                    [Walking]
# voltorb                                   [Walking]
# venonat                                   [Walking]
# venomoth                                  [Walking]
# ursaring                                  [Walking]
# tentacruel                     [Super Rod, Surfing]
# tentacool   [Good Rod, Old Rod, Super Rod, Surfing]
# tangela                                   [Walking]
# sunkern                                   [Walking]
# staryu                        [Good Rod, Super Rod]
# spearow     [Headbutt, Headbutt (Special), Walking]
# snubbull                                  [Walking]
# sneasel                                   [Walking]
# slugma                                    [Walking]
# slowpoke                         [Surfing, Walking]
# skiploom                                  [Walking]
# shellder                      [Good Rod, Super Rod]
# sentret                                   [Walking]
# seaking                        [Super Rod, Surfing]
# sandslash                                 [Walking]
# sandshrew                                 [Walking]
# rattata                                   [Walking]
# raticate                                  [Walking]
# rapidash                           [Trade, Walking]
# qwilfish                                [Super Rod]
# quagsire                         [Surfing, Walking]
# ...                                             ...
# haunter                                   [Walking]
# gyarados                      [Good Rod, Super Rod]
# growlithe                                 [Walking]
# grimer                                    [Walking]
# granbull                                  [Walking]
# golduck                                   [Surfing]
# goldeen     [Good Rod, Old Rod, Super Rod, Surfing]
# golbat                                    [Walking]
# gloom                                     [Walking]
# furret                                    [Walking]
# fearow                                    [Walking]
# exeggcute            [Headbutt, Headbutt (Special)]
# electabuzz                                [Walking]
# ekans                           [Headbutt, Walking]
# drowzee                                   [Walking]
# donphan                                   [Walking]
# doduo                                     [Walking]
# dodrio                                    [Walking]
# corsola                       [Good Rod, Super Rod]
# clefairy                                  [Walking]
# chinchou                      [Good Rod, Super Rod]
# chansey                                   [Walking]
# caterpie    [Headbutt, Headbutt (Special), Walking]
# butterfree  [Headbutt, Headbutt (Special), Walking]
# bellsprout                                [Walking]
# beedrill                                 [Headbutt]
# arbok                                     [Walking]
# aipom                [Headbutt, Headbutt (Special)]
# aerodactyl                                  [Trade]
# abra                                      [Walking]
#
#                                              Routes Available  \
# Pokemon
# zubat       [kanto-route-10, kanto-route-3, kanto-route-4,...
# xatu                                      [kanto-pewter-city]
# weepinbell                   [kanto-route-24, kanto-route-25]
# weedle                       [kanto-route-26, kanto-route-27]
# vulpix                         [kanto-route-7, kanto-route-8]
# voltorb                                      [kanto-route-10]
# venonat     [kanto-route-10, kanto-route-13, kanto-route-1...
# venomoth    [kanto-route-10, kanto-route-13, kanto-route-1...
# ursaring                                     [kanto-route-28]
# tentacruel  [kanto-cinnabar-island, kanto-pallet-town, kan...
# tentacool   [kanto-cinnabar-island, kanto-pallet-town, kan...
# tangela                      [kanto-route-21, kanto-route-28]
# sunkern                                      [kanto-route-24]
# staryu       [kanto-route-19, kanto-route-20, kanto-route-21]
# spearow     [kanto-route-10, kanto-route-22, kanto-route-2...
# snubbull        [kanto-route-6, kanto-route-7, kanto-route-8]
# sneasel                                      [kanto-route-28]
# slugma       [kanto-route-16, kanto-route-17, kanto-route-18]
# slowpoke                                  [kanto-tohjo-falls]
# skiploom                                     [kanto-route-14]
# shellder    [kanto-pallet-town, kanto-route-26, kanto-rout...
# sentret                                       [kanto-route-1]
# seaking     [kanto-cerulean-city, kanto-route-10, kanto-ro...
# sandslash                    [kanto-route-26, kanto-route-27]
# sandshrew                      [kanto-route-3, kanto-route-4]
# rattata     [kanto-route-1, kanto-route-11, kanto-route-21...
# raticate    [kanto-route-1, kanto-route-10, kanto-route-11...
# rapidash                  [kanto-pewter-city, kanto-route-28]
# qwilfish                     [kanto-route-12, kanto-route-13]
# quagsire    [kanto-route-10, kanto-route-12, kanto-route-1...
# ...                                                       ...
# haunter                                       [kanto-route-8]
# gyarados                                 [kanto-fuchsia-city]
# growlithe                      [kanto-route-7, kanto-route-8]
# grimer       [kanto-route-16, kanto-route-17, kanto-route-18]
# granbull                       [kanto-route-5, kanto-route-6]
# golduck                                       [kanto-route-6]
# goldeen     [kanto-cerulean-city, kanto-route-10, kanto-ro...
# golbat                    [kanto-route-28, kanto-tohjo-falls]
# gloom                         [kanto-route-24, kanto-route-5]
# furret                                        [kanto-route-1]
# fearow      [kanto-route-10, kanto-route-16, kanto-route-1...
# exeggcute                    [kanto-route-26, kanto-route-27]
# electabuzz                                   [kanto-route-10]
# ekans       [kanto-route-26, kanto-route-27, kanto-route-3...
# drowzee                       [kanto-route-11, kanto-route-6]
# donphan                                      [kanto-route-28]
# doduo       [kanto-route-22, kanto-route-26, kanto-route-2...
# dodrio       [kanto-route-26, kanto-route-27, kanto-route-28]
# corsola      [kanto-route-19, kanto-route-20, kanto-route-21]
# clefairy                       [kanto-route-3, kanto-route-4]
# chinchou    [kanto-pallet-town, kanto-route-26, kanto-rout...
# chansey      [kanto-route-13, kanto-route-14, kanto-route-15]
# caterpie    [kanto-route-24, kanto-route-25, kanto-route-2...
# butterfree  [kanto-route-24, kanto-route-25, kanto-route-2...
# bellsprout  [kanto-route-24, kanto-route-25, kanto-route-5...
# beedrill                     [kanto-route-26, kanto-route-27]
# arbok       [kanto-route-26, kanto-route-27, kanto-route-2...
# aipom                        [kanto-route-26, kanto-route-27]
# aerodactyl                                   [kanto-route-14]
# abra        [kanto-route-24, kanto-route-25, kanto-route-5...
#
#                   Times Available
# Pokemon
# zubat       [day, morning, night]
# xatu        [day, morning, night]
# weepinbell  [day, morning, night]
# weedle      [day, morning, night]
# vulpix      [day, morning, night]
# voltorb     [day, morning, night]
# venonat          [morning, night]
# venomoth                  [night]
# ursaring    [day, morning, night]
# tentacruel  [day, morning, night]
# tentacool   [day, morning, night]
# tangela     [day, morning, night]
# sunkern                     [day]
# staryu                    [night]
# spearow     [day, morning, night]
# snubbull           [day, morning]
# sneasel                   [night]
# slugma      [day, morning, night]
# slowpoke    [day, morning, night]
# skiploom           [day, morning]
# shellder    [day, morning, night]
# sentret            [day, morning]
# seaking     [day, morning, night]
# sandslash   [day, morning, night]
# sandshrew          [day, morning]
# rattata     [day, morning, night]
# raticate    [day, morning, night]
# rapidash    [day, morning, night]
# qwilfish    [day, morning, night]
# quagsire    [day, morning, night]
# ...                           ...
# haunter                   [night]
# gyarados    [day, morning, night]
# growlithe   [day, morning, night]
# grimer      [day, morning, night]
# granbull           [day, morning]
# golduck     [day, morning, night]
# goldeen     [day, morning, night]
# golbat      [day, morning, night]
# gloom                     [night]
# furret             [day, morning]
# fearow             [day, morning]
# exeggcute   [day, morning, night]
# electabuzz  [day, morning, night]
# ekans       [day, morning, night]
# drowzee     [day, morning, night]
# donphan     [day, morning, night]
# doduo              [day, morning]
# dodrio             [day, morning]
# corsola            [day, morning]
# clefairy                  [night]
# chinchou    [day, morning, night]
# chansey     [day, morning, night]
# caterpie    [day, morning, night]
# butterfree  [day, morning, night]
# bellsprout  [day, morning, night]
# beedrill    [day, morning, night]
# arbok       [day, morning, night]
# aipom       [day, morning, night]
# aerodactyl  [day, morning, night]
# abra        [day, morning, night]
#
# [94 rows x 3 columns]

# %%
"""
save dataframe to "./Desktop/pokemonLocations.csv
"""
pokemon_location_guide_df.to_csv('~/Desktop/pokemonLocations.csv')
